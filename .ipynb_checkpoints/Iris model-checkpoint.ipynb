# %%
#Step 1 - Import the libraries
import pandas as pd

# %%
#Step 2 - load the data
data = pd.read_csv('Iris.data')# header=None
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 #Step 2 - load the data
# ----> 2 data = pd.read_csv('Iris.data')# header=None
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1729, in TextFileReader._make_engine(self, f, engine)
#    1727     is_text = False
#    1728     mode = "rb"
# -> 1729 self.handles = get_handle(
#    1730     f,
#    1731     mode,
#    1732     encoding=self.options.get("encoding", None),
#    1733     compression=self.options.get("compression", None),
#    1734     memory_map=self.options.get("memory_map", False),
#    1735     is_text=is_text,
#    1736     errors=self.options.get("encoding_errors", "strict"),
#    1737     storage_options=self.options.get("storage_options", None),
#    1738 )
#    1739 assert self.handles is not None
#    1740 f = self.handles.handle
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\common.py:857, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     852 elif isinstance(handle, str):
#     853     # Check whether the filename is to be opened in binary mode.
#     854     # Binary mode does not support 'encoding' and 'newline'.
#     855     if ioargs.encoding and "b" not in ioargs.mode:
#     856         # Encoding
# --> 857         handle = open(
#     858             handle,
#     859             ioargs.mode,
#     860             encoding=ioargs.encoding,
#     861             errors=errors,
#     862             newline="",
#     863         )
#     864     else:
#     865         # Binary mode
#     866         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Iris.data'

# %%
data
#setosa
#versicolor
#verginica
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  NaN     Iris-setosa
# 3    4.6  NaN  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2             NaN
# ..   ...  ...  ...  ...             ...
# 147  6.7  3.0  5.2  2.3  Iris-virginica
# 148  6.3  2.5  5.0  1.9  Iris-virginica
# 149  6.5  3.0  5.2  2.0  Iris-virginica
# 150  6.2  3.4  5.4  2.3  Iris-virginica
# 151  5.9  3.0  5.1  1.8  Iris-virginica
#
# [152 rows x 5 columns]

# %%
data.columns
# Out:
# Int64Index([0, 1, 2, 3, 4], dtype='int64')

# %%
data.columns = ['sepal_length','sepal_width','petal_length','petal_width','label']

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           label
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          NaN     Iris-setosa
# 3             4.6          NaN           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2             NaN
# ..            ...          ...           ...          ...             ...
# 147           6.7          3.0           5.2          2.3  Iris-virginica
# 148           6.3          2.5           5.0          1.9  Iris-virginica
# 149           6.5          3.0           5.2          2.0  Iris-virginica
# 150           6.2          3.4           5.4          2.3  Iris-virginica
# 151           5.9          3.0           5.1          1.8  Iris-virginica
#
# [152 rows x 5 columns]

# %%
#isna()
#isnull()
data.isna()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  label
# 0           False        False         False        False  False
# 1           False        False         False        False  False
# 2           False        False         False         True  False
# 3           False         True         False        False  False
# 4           False        False         False        False   True
# ..            ...          ...           ...          ...    ...
# 147         False        False         False        False  False
# 148         False        False         False        False  False
# 149         False        False         False        False  False
# 150         False        False         False        False  False
# 151         False        False         False        False  False
#
# [152 rows x 5 columns]

# %%
data.isnull()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  label
# 0           False        False         False        False  False
# 1           False        False         False        False  False
# 2           False        False         False         True  False
# 3           False         True         False        False  False
# 4           False        False         False        False   True
# ..            ...          ...           ...          ...    ...
# 147         False        False         False        False  False
# 148         False        False         False        False  False
# 149         False        False         False        False  False
# 150         False        False         False        False  False
# 151         False        False         False        False  False
#
# [152 rows x 5 columns]

# %%
data.isna().sum()
# Out:
# sepal_length    4
# sepal_width     8
# petal_length    6
# petal_width     5
# label           5
# dtype: int64

# %%
#dropna
data.dropna()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           label
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 5             5.4          3.9           1.7          0.4     Iris-setosa
# 8             4.6          3.4           1.4          0.3     Iris-setosa
# 10            4.4          2.9           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 147           6.7          3.0           5.2          2.3  Iris-virginica
# 148           6.3          2.5           5.0          1.9  Iris-virginica
# 149           6.5          3.0           5.2          2.0  Iris-virginica
# 150           6.2          3.4           5.4          2.3  Iris-virginica
# 151           5.9          3.0           5.1          1.8  Iris-virginica
#
# [138 rows x 5 columns]

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           label
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          NaN     Iris-setosa
# 3             4.6          NaN           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2             NaN
# ..            ...          ...           ...          ...             ...
# 147           6.7          3.0           5.2          2.3  Iris-virginica
# 148           6.3          2.5           5.0          1.9  Iris-virginica
# 149           6.5          3.0           5.2          2.0  Iris-virginica
# 150           6.2          3.4           5.4          2.3  Iris-virginica
# 151           5.9          3.0           5.1          1.8  Iris-virginica
#
# [152 rows x 5 columns]

# %%
data.dropna(thresh=4)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           label
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          NaN     Iris-setosa
# 3             4.6          NaN           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2             NaN
# ..            ...          ...           ...          ...             ...
# 147           6.7          3.0           5.2          2.3  Iris-virginica
# 148           6.3          2.5           5.0          1.9  Iris-virginica
# 149           6.5          3.0           5.2          2.0  Iris-virginica
# 150           6.2          3.4           5.4          2.3  Iris-virginica
# 151           5.9          3.0           5.1          1.8  Iris-virginica
#
# [146 rows x 5 columns]

# %%
data.dropna(how='all')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           label
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          NaN     Iris-setosa
# 3             4.6          NaN           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2             NaN
# ..            ...          ...           ...          ...             ...
# 147           6.7          3.0           5.2          2.3  Iris-virginica
# 148           6.3          2.5           5.0          1.9  Iris-virginica
# 149           6.5          3.0           5.2          2.0  Iris-virginica
# 150           6.2          3.4           5.4          2.3  Iris-virginica
# 151           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data.dropna(subset=['label'],inplace=True)

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           label
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          NaN     Iris-setosa
# 3             4.6          NaN           1.5          0.2     Iris-setosa
# 5             5.4          3.9           1.7          0.4     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 147           6.7          3.0           5.2          2.3  Iris-virginica
# 148           6.3          2.5           5.0          1.9  Iris-virginica
# 149           6.5          3.0           5.2          2.0  Iris-virginica
# 150           6.2          3.4           5.4          2.3  Iris-virginica
# 151           5.9          3.0           5.1          1.8  Iris-virginica
#
# [147 rows x 5 columns]

# %%
#impute = substitute
data.fillna(3.7)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           label
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          3.7     Iris-setosa
# 3             4.6          3.7           1.5          0.2     Iris-setosa
# 5             5.4          3.9           1.7          0.4     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 147           6.7          3.0           5.2          2.3  Iris-virginica
# 148           6.3          2.5           5.0          1.9  Iris-virginica
# 149           6.5          3.0           5.2          2.0  Iris-virginica
# 150           6.2          3.4           5.4          2.3  Iris-virginica
# 151           5.9          3.0           5.1          1.8  Iris-virginica
#
# [147 rows x 5 columns]
